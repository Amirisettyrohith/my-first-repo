# %% [markdown]
# Hardware:The components that we can touch physically
# ex:Monitor,keyboard,mouse,etc..,
# Software:The components that we cannot touch but we can use them for running the applications
# ex:google docs,whatsapp,etc..,
